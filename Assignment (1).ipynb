# %% [markdown]
# Install the following packages using pip:
# ```
# pip install ipywidgets
# pip install pyaudio
# pip install vosk
# pip install transformers
# pip install torch
# ```

# %%
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (8.19.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: decorator in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets
from IPython.display import display
from queue import Queue
from threading import Thread

messages = Queue()
recordings = Queue()

record_button = widgets.Button(
    description='Record',
    disabled=False,
    button_style='success',
    tooltip='Record',
    icon='microphone'
)


stop_button = widgets.Button(
    description='Stop',
    disabled=False,
    button_style='warning',
    tooltip='Stop',
    icon='stop'
)

output = widgets.Output()

def start_recording(data):
    messages.put(True)
    
    with output:
        display("Starting...")
        record = Thread(target=record_microphone)
        record.start()
        transcribe = Thread(target=speech_recognition, args=(output,))
        transcribe.start()

def stop_recording(data):
    with output:
        messages.get()
        display("Stopped.")
    
record_button.on_click(start_recording)
stop_button.on_click(stop_recording)

display(record_button, stop_button, output)

# %%
# !python -m pip install pyaudio
# Out:
# Collecting pyaudio
#   Downloading PyAudio-0.2.14-cp38-cp38-win_amd64.whl.metadata (2.7 kB)
# Downloading PyAudio-0.2.14-cp38-cp38-win_amd64.whl (164 kB)
#    ---------------------------------------- 0.0/164.1 kB ? eta -:--:--
#    ---- ---------------------------------- 20.5/164.1 kB 320.0 kB/s eta 0:00:01
#    --------- ----------------------------- 41.0/164.1 kB 393.8 kB/s eta 0:00:01
#    ------------------- ------------------- 81.9/164.1 kB 573.4 kB/s eta 0:00:01
#    -------------------------------------- 164.1/164.1 kB 818.2 kB/s eta 0:00:00
# Installing collected packages: pyaudio
# Successfully installed pyaudio-0.2.14

# %% [markdown]
# Note the index of the desired input device (e.g., your microphone) to use it in the recording script.

# %%
import pyaudio
p = pyaudio.PyAudio()
for i in range(p.get_device_count()):
    print(p.get_device_info_by_index(i))

p.terminate()
# Out:
# {'index': 0, 'structVersion': 2, 'name': 'Microsoft Sound Mapper - Input', 'hostApi': 0, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.09, 'defaultLowOutputLatency': 0.09, 'defaultHighInputLatency': 0.18, 'defaultHighOutputLatency': 0.18, 'defaultSampleRate': 44100.0}
# {'index': 1, 'structVersion': 2, 'name': 'External Microphone (Realtek(R)', 'hostApi': 0, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.09, 'defaultLowOutputLatency': 0.09, 'defaultHighInputLatency': 0.18, 'defaultHighOutputLatency': 0.18, 'defaultSampleRate': 44100.0}
# {'index': 2, 'structVersion': 2, 'name': 'Microphone Array (IntelÂ® Smart ', 'hostApi': 0, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.09, 'defaultLowOutputLatency': 0.09, 'defaultHighInputLatency': 0.18, 'defaultHighOutputLatency': 0.18, 'defaultSampleRate': 44100.0}
# {'index': 3, 'structVersion': 2, 'name': 'Microsoft Sound Mapper - Output', 'hostApi': 0, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.09, 'defaultLowOutputLatency': 0.09, 'defaultHighInputLatency': 0.18, 'defaultHighOutputLatency': 0.18, 'defaultSampleRate': 44100.0}
# {'index': 4, 'structVersion': 2, 'name': 'Headphones (Realtek(R) Audio)', 'hostApi': 0, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.09, 'defaultLowOutputLatency': 0.09, 'defaultHighInputLatency': 0.18, 'defaultHighOutputLatency': 0.18, 'defaultSampleRate': 44100.0}
# {'index': 5, 'structVersion': 2, 'name': 'Speakers (Realtek(R) Audio)', 'hostApi': 0, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.09, 'defaultLowOutputLatency': 0.09, 'defaultHighInputLatency': 0.18, 'defaultHighOutputLatency': 0.18, 'defaultSampleRate': 44100.0}
# {'index': 6, 'structVersion': 2, 'name': 'Primary Sound Capture Driver', 'hostApi': 1, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.12, 'defaultLowOutputLatency': 0.0, 'defaultHighInputLatency': 0.24, 'defaultHighOutputLatency': 0.0, 'defaultSampleRate': 44100.0}
# {'index': 7, 'structVersion': 2, 'name': 'External Microphone (Realtek(R) Audio)', 'hostApi': 1, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.12, 'defaultLowOutputLatency': 0.0, 'defaultHighInputLatency': 0.24, 'defaultHighOutputLatency': 0.0, 'defaultSampleRate': 44100.0}
# {'index': 8, 'structVersion': 2, 'name': 'Microphone Array (IntelÂ® Smart Sound Technology for Digital Microphones)', 'hostApi': 1, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.12, 'defaultLowOutputLatency': 0.0, 'defaultHighInputLatency': 0.24, 'defaultHighOutputLatency': 0.0, 'defaultSampleRate': 44100.0}
# {'index': 9, 'structVersion': 2, 'name': 'Primary Sound Driver', 'hostApi': 1, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.0, 'defaultLowOutputLatency': 0.12, 'defaultHighInputLatency': 0.0, 'defaultHighOutputLatency': 0.24, 'defaultSampleRate': 44100.0}
# {'index': 10, 'structVersion': 2, 'name': 'Headphones (Realtek(R) Audio)', 'hostApi': 1, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.0, 'defaultLowOutputLatency': 0.12, 'defaultHighInputLatency': 0.0, 'defaultHighOutputLatency': 0.24, 'defaultSampleRate': 44100.0}
# {'index': 11, 'structVersion': 2, 'name': 'Speakers (Realtek(R) Audio)', 'hostApi': 1, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.0, 'defaultLowOutputLatency': 0.12, 'defaultHighInputLatency': 0.0, 'defaultHighOutputLatency': 0.24, 'defaultSampleRate': 44100.0}
# {'index': 12, 'structVersion': 2, 'name': 'Headphones (Realtek(R) Audio)', 'hostApi': 2, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.0, 'defaultLowOutputLatency': 0.003, 'defaultHighInputLatency': 0.0, 'defaultHighOutputLatency': 0.01, 'defaultSampleRate': 48000.0}
# {'index': 13, 'structVersion': 2, 'name': 'Speakers (Realtek(R) Audio)', 'hostApi': 2, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.0, 'defaultLowOutputLatency': 0.003, 'defaultHighInputLatency': 0.0, 'defaultHighOutputLatency': 0.01, 'defaultSampleRate': 48000.0}
# {'index': 14, 'structVersion': 2, 'name': 'External Microphone (Realtek(R) Audio)', 'hostApi': 2, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.003, 'defaultLowOutputLatency': 0.0, 'defaultHighInputLatency': 0.01, 'defaultHighOutputLatency': 0.0, 'defaultSampleRate': 48000.0}
# {'index': 15, 'structVersion': 2, 'name': 'Microphone Array (IntelÂ® Smart Sound Technology for Digital Microphones)', 'hostApi': 2, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.002, 'defaultLowOutputLatency': 0.0, 'defaultHighInputLatency': 0.01, 'defaultHighOutputLatency': 0.0, 'defaultSampleRate': 48000.0}
# {'index': 16, 'structVersion': 2, 'name': 'Speakers (Realtek HD Audio output with SST)', 'hostApi': 3, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.01, 'defaultLowOutputLatency': 0.01, 'defaultHighInputLatency': 0.04, 'defaultHighOutputLatency': 0.04, 'defaultSampleRate': 48000.0}
# {'index': 17, 'structVersion': 2, 'name': 'Stereo Mix (Realtek HD Audio Stereo input)', 'hostApi': 3, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.01, 'defaultLowOutputLatency': 0.01, 'defaultHighInputLatency': 0.04, 'defaultHighOutputLatency': 0.04, 'defaultSampleRate': 48000.0}
# {'index': 18, 'structVersion': 2, 'name': 'Microphone (Realtek HD Audio Mic input)', 'hostApi': 3, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.01, 'defaultLowOutputLatency': 0.01, 'defaultHighInputLatency': 0.04, 'defaultHighOutputLatency': 0.04, 'defaultSampleRate': 44100.0}
# {'index': 19, 'structVersion': 2, 'name': 'Headphones (Realtek HD Audio 2nd output with SST)', 'hostApi': 3, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.01, 'defaultLowOutputLatency': 0.01, 'defaultHighInputLatency': 0.04, 'defaultHighOutputLatency': 0.04, 'defaultSampleRate': 48000.0}
# {'index': 20, 'structVersion': 2, 'name': 'Speakers (Nahimic mirroring Wave Speaker)', 'hostApi': 3, 'maxInputChannels': 0, 'maxOutputChannels': 2, 'defaultLowInputLatency': 0.01, 'defaultLowOutputLatency': 0.01, 'defaultHighInputLatency': 0.04, 'defaultHighOutputLatency': 0.04, 'defaultSampleRate': 44100.0}
# {'index': 21, 'structVersion': 2, 'name': 'Microphone Array 1 ()', 'hostApi': 3, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.01, 'defaultLowOutputLatency': 0.01, 'defaultHighInputLatency': 0.04, 'defaultHighOutputLatency': 0.04, 'defaultSampleRate': 48000.0}
# {'index': 22, 'structVersion': 2, 'name': 'Microphone Array 2 ()', 'hostApi': 3, 'maxInputChannels': 2, 'maxOutputChannels': 0, 'defaultLowInputLatency': 0.01, 'defaultLowOutputLatency': 0.01, 'defaultHighInputLatency': 0.04, 'defaultHighOutputLatency': 0.04, 'defaultSampleRate': 48000.0}
# {'index': 23, 'structVersion': 2, 'name': 'Speakers (Nahimic Easy Surround)', 'hostApi': 3, 'maxInputChannels': 0, 'maxOutputChannels': 8, 'defaultLowInputLatency': 0.01, 'defaultLowOutputLatency': 0.01, 'defaultHighInputLatency': 0.04, 'defaultHighOutputLatency': 0.04, 'defaultSampleRate': 48000.0}

# %% [markdown]
# The record_microphone function handles recording audio from the selected input device. Configure the CHANNELS, FRAME_RATE, RECORD_SECONDS, AUDIO_FORMAT, and input_device_index according to your setup.

# %%
CHANNELS = 1
FRAME_RATE = 16000
RECORD_SECONDS = 5
AUDIO_FORMAT = pyaudio.paInt16
SAMPLE_SIZE = 2

def record_microphone(chunk=1024):
    p = pyaudio.PyAudio()

    stream = p.open(format=AUDIO_FORMAT,
                    channels=CHANNELS,
                    rate=FRAME_RATE,
                    input=True,
                    input_device_index=7,  # Use the index of your microphone
                    frames_per_buffer=chunk)

    frames = []

    while not messages.empty():
        data = stream.read(chunk)
        frames.append(data)
        if len(frames) >= (FRAME_RATE * RECORD_SECONDS) / chunk:
            recordings.put(frames.copy())
            frames = []

    stream.stop_stream()
    stream.close()
    p.terminate()

# %%
# %pip install vosk
# %pip install transformers
# %pip install torch
# Out:
# Collecting vosk
#   Using cached vosk-0.3.45-py3-none-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: cffi>=1.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from vosk) (1.16.0)
# Requirement already satisfied: requests in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from vosk) (2.31.0)
# Collecting srt (from vosk)
#   Using cached srt-3.5.3.tar.gz (28 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from vosk) (4.66.2)
# Collecting websockets (from vosk)
#   Downloading websockets-12.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: pycparser in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0->vosk) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from requests->vosk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from requests->vosk) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from requests->vosk) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from requests->vosk) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from tqdm->vosk) (0.4.6)
# Using cached vosk-0.3.45-py3-none-win_amd64.whl (14.0 MB)
# Downloading websockets-12.0-cp312-cp312-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/125.0 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/125.0 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/125.0 kB 435.7 kB/s eta 0:00:01
#    ------------ -------------------------- 41.0/125.0 kB 326.8 kB/s eta 0:00:01
#    ---------------------------- ---------- 92.2/125.0 kB 521.8 kB/s eta 0:00:01
#    -------------------------------------- 125.0/125.0 kB 667.1 kB/s eta 0:00:00
# Building wheels for collected packages: srt
#   Building wheel for srt (pyproject.toml): started
#   Building wheel for srt (pyproject.toml): finished with status 'done'
#   Created wheel for srt: filename=srt-3.5.3-py3-none-any.whl size=22556 sha256=d985e7b3b68cd360c599f05c9fbf863515991dab31be3c38472b9968cda4664c
#   Stored in directory: c:\users\hemanth siddharth\appdata\local\pip\cache\wheels\7e\75\5b\e1d5c3756631e4bda806f6cc9640153b39484bb6f7b0b8def3
# Successfully built srt
# Installing collected packages: websockets, srt, vosk
# Successfully installed srt-3.5.3 vosk-0.3.45 websockets-12.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting transformers
#   Using cached transformers-4.41.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.23.0 (from transformers)
#   Using cached huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.5.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/42.0 kB 330.3 kB/s eta 0:00:01
#      --------------------------- ---------- 30.7/42.0 kB 325.1 kB/s eta 0:00:01
#      -------------------------------------- 42.0/42.0 kB 253.9 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers)
#   Downloading tokenizers-0.19.1-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.3-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.10.0)
# Requirement already satisfied: colorama in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2023.11.17)
# Using cached transformers-4.41.2-py3-none-any.whl (9.1 MB)
# Using cached huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
# Downloading regex-2024.5.15-cp312-cp312-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.5 kB ? eta -:--:--
#    --------- ------------------------------ 61.4/268.5 kB 1.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 71.7/268.5 kB 1.3 MB/s eta 0:00:01
#    -------------------- ----------------- 143.4/268.5 kB 950.9 kB/s eta 0:00:01
#    ----------------------------------- ---- 235.5/268.5 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 268.5/268.5 kB 1.1 MB/s eta 0:00:00
# Downloading safetensors-0.4.3-cp312-none-win_amd64.whl (289 kB)
#    ---------------------------------------- 0.0/289.4 kB ? eta -:--:--
#    ------------------------------- -------- 225.3/289.4 kB 6.7 MB/s eta 0:00:01
#    --------------------------------- ------ 245.8/289.4 kB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  286.7/289.4 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 289.4/289.4 kB 2.0 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp312-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------- -------------------------------- 0.4/2.2 MB 8.9 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.2 MB 8.0 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.2 MB 5.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 6.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 6.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.0/2.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 7.0 MB/s eta 0:00:00
# Installing collected packages: safetensors, regex, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.21.4
#     Uninstalling huggingface-hub-0.21.4:
#       Successfully uninstalled huggingface-hub-0.21.4
# Successfully installed huggingface-hub-0.23.4 regex-2024.5.15 safetensors-0.4.3 tokenizers-0.19.1 transformers-4.41.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (2.2.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: filelock in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hemanth siddharth\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# The speech_recognition function uses the vosk model for converting recorded audio into text.

# %%
import subprocess
import json
from vosk import Model, KaldiRecognizer
import time

model = Model(model_name="vosk-model-small-en-us-0.15")
rec = KaldiRecognizer(model, FRAME_RATE)
rec.SetWords(True)
    
def speech_recognition(output):
    
    while not messages.empty():
        frames = recordings.get()
        
        rec.AcceptWaveform(b''.join(frames))
        result = rec.Result()
        text = json.loads(result)["text"]
        
        cased = subprocess.check_output('python recasepunc/recasepunc.py predict recasepunc/checkpoint', shell=True, text=True, input=text)
        output.append_stdout(cased)
        time.sleep(1)

# %% [markdown]
# Conclusion
#
# This project demonstrates a basic implementation of a voice recording and speech recognition system using Python. The system can be extended with additional features such as handling longer recordings, integrating with other NLP models for further processing, and enhancing the user interface.
